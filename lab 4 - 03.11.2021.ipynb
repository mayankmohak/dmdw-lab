# %% [markdown]
# <a href="https://colab.research.google.com/github/Bighnaraj19/DMDW/blob/main/assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("/content/Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris.plot()

# %%
iris.hist();

# %%
iris.boxplot()

# %%
X = ['Group A','Group B','Group C','Group D']
pre = np.array([19,6,11,9])
post = np.array([15,11,9,8])
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, pre, 0.4, label = 'Pre')
plt.bar(X_axis + 0.2, post, 0.4, label = 'Post')
  
plt.xticks(X_axis, X)
plt.xlabel("PRE")
plt.ylabel("POST")
plt.title("PRE-POST PLOT")
plt.legend()
plt.show()

# %%
x1 = np.linspace(0,100,20)
x2 = np.linspace(0,100,20)
x3 = np.linspace(0,100,20)

# %%
y1 = np.sin(x1)
plt.plot(y1)

# %%
y2 = np.cos(x2)
plt.plot(y2)

# %%
y3 = np.tan(x3)
plt.plot(y3)

# %%
h = plt.plot(y1,y2,y3)

# %%
x =[5,2,9,4,7]
y = [10,5,8,4,2]

# %%
plt.scatter(x,y)
plt.title("XY - Scatter plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend(loc="upper left");
# Out:
# No handles with labels found to put in legend.
